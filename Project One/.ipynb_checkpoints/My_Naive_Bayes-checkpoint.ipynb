# %%
### This is a Naive Bayes Classification Class
import nltk
from nltk import word_tokenize
import numpy as npy
import re
class MyNaiveBayes:
    def __init__(self):
    #initializing class variables
        self.classes = ["positive(+)", "negative(-)"]
        self.classNums = len(self.classes) 
        self.chanceOfOcc = {c : dict() for c in range(self.classNums) } 
        self.zvadzidza = [0 for i in range(self.classNums)]
        self.dictionaryOfWords = []
             
    
     #reads the files to be used
    def readDocs(self, document):
        retThus = []
        with open(document) as f:
            for line in f.readlines():
                this = line.split('\n')
                this = this[0].split('\t')
                revs = re.sub(r"[,/?!-()*&^%|'.,]","",this[0])
                bOw = word_tokenize(this[0].lower())
                label = int(this[1])
                retThus.append((self.mkBigram(bOw), label))
        return retThus

    def trainingDay(self, litium):
        classNumber = [0 for i in range(self.classNums)]
        ndoc = len(litium)
        words = {c : dict() for c in range(self.classNums)}
        for book in litium:
            review = book[0]
            label = book[-1]
            classNumber[label] += 1
            for word in review:
                if word in words[label].keys():
                    words[label][word] += 1
                else:
                    words[label][word] = 1
                    
        for index in range(len(self.classes)):
            self.zvadzidza[index] = npy.log(classNumber[index]/ndoc)
            self.dictionaryOfWords += list(words[index].keys())
        self.dictionaryOfWords = set(self.dictionaryOfWords)
        print (len(self.dictionaryOfWords))
        
        for index in range(len(self.classes)):
            for word in self.dictionaryOfWords:
                if word in words[index]:
                    self.chanceOfOcc[index][word] = npy.log((words[index][word]+1)/(sum(words[index].values())+len(self.dictionaryOfWords)))
                else:
                    self.chanceOfOcc[index][word] = npy.log((1)/(sum(words[index].values())+len(self.dictionaryOfWords)))

    #trains the classifier using input (type = text) referenced as books
    def trainor(self, books, test=False, split_ratio=0.30):
        litium = []
        for bk in books:
            for review in self.readDocs(bk):
                litium.append(review)
                
        if test:
            npy.random.shuffle(litium)
            splice = int(len(litium) * split_ratio)
            test_data = litium[:splice]
            train_data = litium[splice:]
            self.trainingDay(train_data)
            
            test_acc = self.testor(test_data)
            print ("You have", len(test_data)," test data")
            print ("Testing accuracy approximation: ",test_acc)
            train_acc = self.testor(train_data)
            print ("You have", len(train_data)," train data")
            print ("Training accuracy approximation: ",train_acc*100, "%")
        else:
            self.trainingDay(litium)

    
    #takes a token(s) as input and returns the numerical value of the class    
    def predictor(self, sentence):
        import operator
        tot = dict()
        for i in range(self.classNums):
            tot[i] = self.zvadzidza[i]
            for word in sentence:
                if word in self.dictionaryOfWords:
                    tot[i] += self.chanceOfOcc[i][word]
        return max(tot.items(), key=operator.itemgetter(1))[0]
    
    
    def testThisFile(self, zitaReFile):
        cols = []
        with open(zitaReFile) as f:
            for line in f.readlines():
                print(line,self.prediction(line))
                cols.append(self.prediction(line))
        
        with open('results.txt', 'w') as f:
            for cl in cols:
                print(line, self.prediction(line))
                f.write(str(cl)+"\n")    
        
                    
    #turns single words into bigrams for more efficient analysis and training           
    def mkBigram(self, words):
        data = []
        new = ['<s>'] + words + ['</s>']
        for i in range(len(new)-1):
            data.append(new[i]+'<>'+new[i+1])
        return data
    
    
    #tokenizes sentence, after which it uses the sentence to predict and assign the input to a class
    def prediction(self, text):
        sent = self.mkBigram(word_tokenize(text))
        return self.predictor(sent)
    
    def testor(self, data):
        allT = len(data)
        true = 0
        for book in data:
            reviews = book[0]
            column = book[-1]
            i = self.predictor(reviews)
            if (i == column): true += 1
        return true / allT

        
    #using already predefined labels, this function computes the accuracy of the mdel by checking the percentage of predictions that are akin to actual assignments
    def accuracy(self, output, actual):
        columnOutput = []
        actualColumns = []
        colRatio = 0
        
        with open(actual) as m:
            for line in m.readlines():
                mutupo = int(line)
                actualColumns.append(mutupo)
                
        with open(output) as m:
            for line in m.readlines():
                mutupo = int(line)
                columnOutput.append(mutupo)

# %%
classifier1 = MyNaiveBayes()
classifier1.train(["./Project One/sentiment_labelled_sentences/amazon_cells_labelled.txt",
                  "./Project One/sentiment_labelled_sentences/imdb_labelled.txt",
                  "./Project One/sentiment_labelled_sentences/yelp_labelled.txt"],
                 test=True,
                 split_ratio=0.30)
# Out:
# 17155

# %%
classifier1.chanceOfOcc
# Out:
# {0: {'pretty<>trippy': -9.705250005676772,
#   'quality<>product': -10.398397186236718,
#   'sister<>has': -10.398397186236718,
#   'clip<>going': -9.705250005676772,
#   'tick<>sound': -9.705250005676772,
#   'turn<>it': -9.705250005676772,
#   'the<>gently': -10.398397186236718,
#   'chickens<>with': -9.705250005676772,
#   'the<>sergeant': -10.398397186236718,
#   'soup<>-': -9.705250005676772,
#   'characters<>are': -10.398397186236718,
#   'some<>way': -9.705250005676772,
#   '5<>)': -9.705250005676772,
#   'wooden<>floor': -9.705250005676772,
#   'something<>.': -10.398397186236718,
#   'well-done<>.': -10.398397186236718,
#   'of<>boost': -9.705250005676772,
#   'and<>never': -9.705250005676772,
#   "'ll<>never": -9.705250005676772,
#   'missed<>a': -10.398397186236718,
#   'after<>3': -9.705250005676772,
#   'a<>heart': -9.705250005676772,
#   'any<>of': -9.012102825116827,
#   'junk<>.': -9.299784897568609,
#   'hot<>and': -10.398397186236718,
#   'this<>gifted': -10.398397186236718,
#   "n't<>really": -8.606637717008663,
#   'your<>ear': -9.705250005676772,
#   'unwrapped<>it': -9.705250005676772,
#   'refused<>to': -9.705250005676772,
#   'restaurant<>highlighted': -10.398397186236718,
#   'talent<>is': -9.705250005676772,
#   'thanks<>good': -10.398397186236718,
#   'service<>here': -9.299784897568609,
#   'hostess<>and': -9.705250005676772,
#   'flawless<>connection': -10.398397186236718,
#   ',<>bitches': -9.705250005676772,
#   'a<>way': -9.705250005676772,
#   'acting<>sucked': -9.705250005676772,
#   'this<>for': -9.299784897568609,
#   'depth<>.': -9.705250005676772,
#   'not<>take': -9.299784897568609,
#   "'s<>auto-answer": -10.398397186236718,
#   'angle<>and': -10.398397186236718,
#   '3<>months': -9.705250005676772,
#   'they<>keep': -10.398397186236718,
#   'was<>clear': -10.398397186236718,
#   'a<>good': -7.833447828775181,
#   '<s><>probably': -9.705250005676772,
#   'we<>asked': -9.299784897568609,
#   'have<>eaten': -10.398397186236718,
#   '<s><>things': -9.705250005676772,
#   'the<>trap': -10.398397186236718,
#   'turn<>it': -10.409853245580026,
#   'the<>gently': -9.71670606502008,
#   'chickens<>with': -10.409853245580026,
#   'the<>sergeant': -9.71670606502008,
#   'soup<>-': -10.409853245580026,
#   'characters<>are': -9.311240956911915,
#   'some<>way': -10.409853245580026,
#   '5<>)': -10.409853245580026,
#   'wooden<>floor': -10.409853245580026,
#   'something<>.': -9.71670606502008,
#   'well-done<>.': -9.71670606502008,
#   'of<>boost': -10.409853245580026,
#   'and<>never': -10.409853245580026,
#   "'ll<>never": -10.409853245580026,
#   'missed<>a': -9.71670606502008,
#   'after<>3': -10.409853245580026,
#   'a<>heart': -10.409853245580026,
#   'any<>of': -9.311240956911915,
#   'junk<>.': -10.409853245580026,
#   'hot<>and': -9.71670606502008,
#   'this<>gifted': -9.71670606502008,
#   "n't<>really": -10.409853245580026,
#   'your<>ear': -9.311240956911915,
#   'unwrapped<>it': -10.409853245580026,
#   'refused<>to': -10.409853245580026,
#   'restaurant<>highlighted': -9.71670606502008,
#   'talent<>is': -10.409853245580026,
#   'thanks<>good': -9.71670606502008,
#   'service<>here': -10.409853245580026,
#   'hostess<>and': -10.409853245580026,
#   'flawless<>connection': -9.71670606502008,
#   ',<>bitches': -10.409853245580026,
#   'a<>way': -10.409853245580026,
#   'acting<>sucked': -10.409853245580026,
#   'this<>for': -9.311240956911915,
#   'depth<>.': -10.409853245580026,
#   'not<>take': -10.409853245580026,
#   "'s<>auto-answer": -9.71670606502008,
#   'angle<>and': -9.71670606502008,
#   '3<>months': -10.409853245580026,
#   'they<>keep': -9.71670606502008,
#   'was<>clear': -9.71670606502008,
#   'a<>good': -7.414120972026034,
#   '<s><>probably': -10.409853245580026,
#   'we<>asked': -10.409853245580026,
#   'have<>eaten': -9.71670606502008,
#   '<s><>things': -10.409853245580026,
#   'the<>trap': -9.71670606502008,
#   'my<>apple': -10.409853245580026,
#   'movies<>like': -10.409853245580026,
#   'work<>in': -10.409853245580026,
#   'internet<>access': -10.409853245580026,
#   'to<>look': -9.311240956911915,
#   'both<>of': -9.311240956911915,
#   "'m<>driving": -9.71670606502008,
#   'i<>basically': -10.409853245580026,
#   'crãªpe<>was': -9.71670606502008,
#   'clear<>reception': -9.71670606502008,
#   "'s<>the": -9.311240956911915,
#   'pho<>!': -9.71670606502008,
#   'sydney<>greenstreet': -9.71670606502008,
#   'his<>childhood': -10.409853245580026,
#   ',<>there': -9.71670606502008,
#   'exactly<>how': -9.71670606502008,
#   'crostini<>that': -10.409853245580026,
#   'really<>ugly': -10.409853245580026,
#   'are<>supposed': -9.71670606502008,
#   'three<>sizes': -9.71670606502008,
#   'very<>unreliable': -10.409853245580026,
#   'this<>tops': -10.409853245580026,
#   'motorola<>q': -10.409853245580026,
#   'provided<>excellent': -9.71670606502008,
#   'shows<>of': -10.409853245580026,
#   'wrong<>size': -10.409853245580026,
#   'amazing<>meal': -9.71670606502008,
#   'these<>.': -9.71670606502008,
#   'overpriced<>.': -10.409853245580026,
#   'the<>scenes': -9.311240956911915,
#   'everything<>to': -9.71670606502008,
#   'other<>end': -9.71670606502008,
#   'blanket<>of': -9.71670606502008,
#   'interacting<>with': -9.71670606502008,
#   'waaaaaayyyyyyyyyy<>over': -10.409853245580026,
#   'can<>say': -9.023558884460135,
#   'work<>very': -10.409853245580026,
#   'told<>friends': -9.71670606502008,
#   'crowd<>pleaser': -9.71670606502008,
#   'clearly<>.': -10.409853245580026,
#   'far<>better': -10.409853245580026,
#   'central<>character': -9.71670606502008,
#   'so<>this': -9.71670606502008,
#   'total<>brunch': -10.409853245580026,
#   '(<>it': -9.023558884460135,
#   'what<>other': -10.409853245580026,
#   'how<>cool': -10.409853245580026,
#   'he<>actually': -9.71670606502008,
#   'enjoyable<>movie': -9.71670606502008,
#   'address<>book': -9.71670606502008,
#   'was<>cooked': -9.71670606502008,
#   'a<>feature': -9.71670606502008,
#   'no<>bigger': -10.409853245580026,
#   ',<>&': -9.71670606502008,
#   'well<>below': -10.409853245580026,
#   'contstruct<>hinge': -10.409853245580026,
#   'are<>tremendous': -9.71670606502008,
#   'non-linear<>narration': -9.71670606502008,
#   'many<>handsfree': -9.71670606502008,
#   'all..<>i': -10.409853245580026,
#   'awful<>,': -10.409853245580026,
#   'all<>it': -9.71670606502008,
#   'it<>somehow': -10.409853245580026,
#   'the<>stuff': -10.409853245580026,
#   'her<>character': -9.71670606502008,
#   'eggplant<>with': -9.71670606502008,
#   'great<>he': -9.71670606502008,
#   'lightly<>against': -9.71670606502008,
#   'bumpers<>with': -10.409853245580026,
#   'perhaps<>contributory': -10.409853245580026,
#   'wow<>,': -10.409853245580026,
#   'barcelona<>and': -9.71670606502008,
#   'on<>fox': -10.409853245580026,
#   'one<>big': -10.409853245580026,
#   'the<>chicken': -9.311240956911915,
#   'tops<>the': -9.71670606502008,
#   'garbage<>in': -9.71670606502008,
#   'this<>a': -9.023558884460135,
#   'film<>did': -9.71670606502008,
#   'place<>on': -10.409853245580026,
#   '1/2<>a': -10.409853245580026,
#   'party<>to': -10.409853245580026,
#   'and<>has': -8.618093776351971,
#   'art<>.': -9.311240956911915,
#   'mesquite<>flavor': -9.71670606502008,
#   'bother<>-': -10.409853245580026,
#   'for<>wasting': -10.409853245580026,
#   '<s><>omg': -9.311240956911915,
#   'is<>interesting': -9.71670606502008,
#   'fresh<>fish': -9.71670606502008,
#   'cannoli<>are': -9.71670606502008,
#   '<s><>favorite': -9.71670606502008,
#   'to<>identify': -9.71670606502008,
#   'to<>dislike': -10.409853245580026,
#   'quickly<>and': -8.800415333145924,
#   '2<>videos': -10.409853245580026,
#   'pictures<>with': -9.71670606502008,
#   'even<>says': -10.409853245580026,
#   'first<>and': -9.71670606502008,
#   'pleasantly<>suprised': -9.71670606502008,
#   'pcs<>samsung': -9.71670606502008,
#   'to<>sit': -10.409853245580026,
#   'just<>predictable': -10.409853245580026,
#   'made<>me': -9.71670606502008,
#   '<s><>maybe': -10.409853245580026,
#   'being<>like': -9.71670606502008,
#   '2<>.': -10.409853245580026,
#   '-<>service': -10.409853245580026,
#   'it<>to': -9.71670606502008,
#   'tasty<>bowl': -9.71670606502008,
#   'singing<>.': -10.409853245580026,
#   'disappointed<>.': -9.023558884460135,
#   'paid<>.': -10.409853245580026,
#   'script<>is': -10.409853245580026,
#   'date<>night': -9.71670606502008,
#   'inspiring<>to': -9.71670606502008,
#   'jokes<>to': -10.409853245580026,
#   'the<>major': -10.409853245580026,
#   'fail<>.': -10.409853245580026,
#   'with<>three': -9.71670606502008,
#   'the<>amount': -9.311240956911915,
#   'all<>good': -9.71670606502008,
#   'or<>win': -9.71670606502008,
#   'ringtones<>or': -9.71670606502008,
#   'fact<>joe': -10.409853245580026,
#   'the<>downtown': -9.71670606502008,
#   'into<>the': -9.311240956911915,
#   'trying<>hard': -10.409853245580026,
#   'they<>debated': -10.409853245580026,
#   'tried<>to': -10.409853245580026,
#   'to<>rice': -10.409853245580026,
#   'catching<>the': -10.409853245580026,
#   'being<>perfect': -9.71670606502008,
#   'is<>when': -9.71670606502008,
#   'stupid<>.': -10.409853245580026,
#   'alike<>.': -9.71670606502008,
#   'folks<>at': -9.71670606502008,
#   'to<>seperate': -9.71670606502008,
#   'am<>so': -9.311240956911915,
#   'was<>creamy': -9.71670606502008,
#   'i<>kept': -10.409853245580026,
#   'increase<>the': -9.71670606502008,
#   'up<>before': -10.409853245580026,
#   '<s><>first': -10.409853245580026,
#   'unless<>i': -10.409853245580026,
#   'movie<>``': -10.409853245580026,
#   "''<>in": -9.71670606502008,
#   'bordered<>on': -10.409853245580026,
#   'ear<>loops': -10.409853245580026,
#   'them<>were': -9.71670606502008,
#   'tables<>outside': -10.409853245580026,
#   'patriotism<>that': -10.409853245580026,
#   'else<>.': -10.409853245580026,
#   'the<>logitech': -10.409853245580026,
#   'from<>riz': -9.71670606502008,
#   'form<>of': -9.71670606502008,
#   'earth<>as': -10.409853245580026,
#   'money<>with': -10.409853245580026,
#   'this<>sooner': -9.71670606502008,
#   'just<>becomes': -10.409853245580026,
#   'also<>incredible': -9.71670606502008,
#   'dissapointing<>performance': -10.409853245580026,
#   'and<>white': -9.023558884460135,
#   "prelude<>''": -9.71670606502008,
#   'the<>creature': -9.71670606502008,
#   'boring<>moment': -9.71670606502008,
#   'the<>charge': -9.71670606502008,
#   'should<>and': -9.71670606502008,
#   '--<>at': -9.71670606502008,
#   'for<>the': -7.2317994152320795,
#   'vodka<>excellent': -9.71670606502008,
#   'natural<>eye': -9.71670606502008,
#   'servers<>are': -10.409853245580026,
#   'owning<>an': -9.71670606502008,
#   'and<>being': -10.409853245580026,
#   'freezes<>frequently4': -10.409853245580026,
#   'unhealthy<>meal': -10.409853245580026,
#   'made<>wrong': -10.409853245580026,
#   'brian<>keith': -9.71670606502008,
#   '3<>times': -10.409853245580026,
#   'become<>a': -9.311240956911915,
#   'to<>give': -9.311240956911915,
#   'that<>again': -10.409853245580026,
#   'heart<>at': -9.71670606502008,
#   'solid<>keyboard': -9.71670606502008,
#   'end<>could': -9.71670606502008,
#   'display<>,': -9.71670606502008,
#   'the<>cutouts': -9.71670606502008,
#   'no<>one': -10.409853245580026,
#   'expect<>from': -9.71670606502008,
#   'a<>european': -9.71670606502008,
#   'in<>market': -9.71670606502008,
#   'last<>)': -10.409853245580026,
#   'version<>,': -10.409853245580026,
#   'was<>mediocre': -10.409853245580026,
#   '2<>cellphones': -10.409853245580026,
#   '<s><>penne': -9.71670606502008,
#   'compelling<>,': -9.71670606502008,
#   ',<>aerial': -9.71670606502008,
#   'still<>great': -9.71670606502008,
#   'acting<>is': -9.71670606502008,
#   'it<>are': -9.71670606502008,
#   '(<>shocking': -9.71670606502008,
#   'are<>difficult': -10.409853245580026,
#   'needs<>a': -10.409853245580026,
#   'it<>off': -9.71670606502008,
#   'patron<>!': -10.409853245580026,
#   'me<>know': -9.71670606502008,
#   'quick<>glance': -9.71670606502008,
#   'a<>truly': -10.409853245580026,
#   'great<>earpiece': -9.71670606502008,
#   'for<>and': -9.71670606502008,
#   'late<>may': -9.71670606502008,
#   'and<>another': -9.71670606502008,
#   'to<>really': -9.71670606502008,
#   'almost<>non-existent': -10.409853245580026,
#   'you<>occupied': -10.409853245580026,
#   'big<>.': -10.409853245580026,
#   'casing<>around': -10.409853245580026,
#   'calls<>drop': -10.409853245580026,
#   '(<>env': -10.409853245580026,
#   'and<>was': -9.311240956911915,
#   'gooodd<>.': -9.71670606502008,
#   'to<>life': -9.311240956911915,
#   "i<>'d": -9.023558884460135,
#   'one<>,': -9.71670606502008,
#   'but<>more': -10.409853245580026,
#   'wouldnt<>see': -10.409853245580026,
#   '<s><>appetite': -10.409853245580026,
#   'i<>gave': -9.311240956911915,
# ...
#   'ended<>,': -10.409853245580026,
#   'quinn<>.': -9.71670606502008,
#   'tech<>support': -10.409853245580026,
#   'from<>tucson': -9.71670606502008,
#   'and<>generous': -9.71670606502008,
#   'how<>retarded': -10.409853245580026,
#   'of<>nuns': -9.71670606502008,
#   'other<>nationalities': -9.71670606502008,
#   'that<>fresh': -10.409853245580026,
#   'for<>anyone': -9.71670606502008,
#   'is<>john': -9.71670606502008,
#   'more<>intelligent': -10.409853245580026,
#   'the<>job': -9.311240956911915,
#   'i<>checked': -10.409853245580026,
#   'let<>alone': -10.409853245580026,
#   '...<>and': -9.311240956911915,
#   'clip<>.': -10.409853245580026,
#   'are<>often': -9.71670606502008,
#   'not<>rent': -10.409853245580026,
#   'with<>his': -9.311240956911915,
#   'disappointed<>!': -9.71670606502008,
#   'began<>before': -10.409853245580026,
#   'name<>callings': -10.409853245580026,
#   'the<>money': -10.409853245580026,
#   'awesome<>device': -9.71670606502008,
#   'chemistry<>,': -9.71670606502008,
#   'to<>change': -10.409853245580026,
#   'family<>atmosphere': -9.71670606502008,
#   'the<>possibility': -10.409853245580026,
#   'area<>.': -9.311240956911915,
#   'and<>seated': -9.311240956911915,
#   'for<>23': -9.71670606502008,
#   'of<>long': -9.71670606502008,
#   'one<>considers': -9.71670606502008,
#   'was<>robert': -9.71670606502008,
#   'frankly<>,': -10.409853245580026,
#   'drain<>your': -10.409853245580026,
#   'generous<>in': -9.71670606502008,
#   'are<>good': -9.71670606502008,
#   'perfectly<>so': -9.71670606502008,
#   'that<>not': -9.71670606502008,
#   'should<>.': -10.409853245580026,
#   'is<>soooo': -9.71670606502008,
#   'low<>budget': -10.409853245580026,
#   'going<>for': -10.409853245580026,
#   'job<>done': -9.311240956911915,
#   'a<>flick': -10.409853245580026,
#   '<s><>a': -8.011957972781655,
#   'was<>stale': -10.409853245580026,
#   'put<>their': -9.71670606502008,
#   'riveted<>to': -9.71670606502008,
#   'painful<>to': -10.409853245580026,
#   'disappointing<>aspects': -10.409853245580026,
#   'be<>amazing': -10.409853245580026,
#   'extra<>plus': -9.71670606502008,
#   'heat<>.': -9.71670606502008,
#   'chicken<>on': -9.311240956911915,
#   'the<>cape': -9.71670606502008,
#   'service<>experience': -10.409853245580026,
#   'now<>i': -10.409853245580026,
#   'vegetables<>)': -10.409853245580026,
#   'here<>did': -10.409853245580026,
#   'and<>charlie': -9.71670606502008,
#   'pics<>are': -9.71670606502008,
#   'spot<>when': -9.71670606502008,
#   "'re<>looking": -9.71670606502008,
#   'wow<>!': -9.71670606502008,
#   'in<>``': -9.71670606502008,
#   ',<>or': -8.33041170390019,
#   'ok<>)': -10.409853245580026,
#   'every<>element': -10.409853245580026,
#   'are<>enough': -10.409853245580026,
#   'his<>performance': -9.71670606502008,
#   'great<>item': -9.71670606502008,
#   '<s><>uncomfortable': -10.409853245580026,
#   'bad<>customer': -10.409853245580026,
#   'riingtones<>are': -10.409853245580026,
#   'town<>for': -9.71670606502008,
#   'not<>use': -10.409853245580026,
#   'who<>changes': -9.71670606502008,
#   'faux<>home': -9.71670606502008,
#   'was<>still': -9.311240956911915,
#   '2<>days': -10.409853245580026,
#   'still<>,': -9.311240956911915,
#   'for<>dessert': -9.71670606502008,
#   'spot<>on': -9.71670606502008,
#   'sandwich<>,': -9.71670606502008,
#   'the<>great': -9.311240956911915,
#   'film<>over': -9.71670606502008,
#   'and<>cumbersome': -10.409853245580026,
#   'my<>through': -10.409853245580026,
#   'ice<>cold': -9.71670606502008,
#   "'m<>trying": -10.409853245580026,
#   'the<>spaghetti': -10.409853245580026,
#   '<s><>phone': -9.71670606502008,
#   'price<>i.e': -9.71670606502008,
#   'worked<>and': -10.409853245580026,
#   'little<>comedy': -10.409853245580026,
#   'years<>old': -9.71670606502008,
#   'but<>which': -9.71670606502008,
#   '-<>a': -9.71670606502008,
#   'when<>he': -9.311240956911915,
#   'by<>strident': -10.409853245580026,
#   'new<>there': -10.409853245580026,
#   '<s><>once': -9.71670606502008,
#   'skimp<>on': -9.71670606502008,
#   'contain<>peanuts': -10.409853245580026,
#   "i<>'ll": -8.618093776351971,
#   '/<>phone': -9.71670606502008,
#   'war<>which': -9.71670606502008,
#   'look<>away': -10.409853245580026,
#   'times<>-': -10.409853245580026,
#   'to<>eat': -9.023558884460135,
#   'a<>little': -9.023558884460135,
#   'because<>they': -9.71670606502008,
#   'portions<>are': -10.409853245580026,
#   'service<>people': -10.409853245580026,
#   'which<>she': -9.71670606502008,
#   'film<>highlights': -9.71670606502008,
#   'even<>has': -9.71670606502008,
#   'should<>have': -9.71670606502008,
#   'the<>onion': -9.71670606502008,
#   'a<>weird': -10.409853245580026,
#   'the<>han': -9.71670606502008,
#   'i<>would': -7.770795915964767,
#   'big<>flawed': -10.409853245580026,
#   'and<>clarity': -9.71670606502008,
#   'is<>long': -9.71670606502008,
#   'they<>would': -10.409853245580026,
#   ')<>you': -10.409853245580026,
#   'somehow<>kept': -10.409853245580026,
#   'are<>delicious': -9.71670606502008,
#   'two<>main': -9.71670606502008,
#   'in<>1928': -9.71670606502008,
#   'that<>the': -9.311240956911915,
#   'continuity<>,': -10.409853245580026,
#   'builders<>were': -9.71670606502008,
#   'wasted<>to': -10.409853245580026,
#   'broke<>.': -10.409853245580026,
#   'gripping<>,': -9.311240956911915,
#   'over<>a': -10.409853245580026,
#   'film<>artist': -9.71670606502008,
#   'of<>s***': -10.409853245580026,
#   'hell<>you': -10.409853245580026,
#   'see<>.': -9.71670606502008,
#   'is<>clearly': -10.409853245580026,
#   'functions<>.': -9.71670606502008,
#   'a<>fabulous': -9.71670606502008,
#   'with<>everything': -10.409853245580026,
#   'all<>enjoy': -9.71670606502008,
#   'earpieces<>provided': -9.71670606502008,
#   'on<>it': -9.023558884460135,
#   'noise<>cancelling': -9.71670606502008,
#   'i<>realized': -9.71670606502008,
#   'a<>bunch': -10.409853245580026,
#   'more<>attention': -10.409853245580026,
#   'the<>ball': -10.409853245580026,
#   'not<>overly': -9.71670606502008,
#   'you<>love': -10.409853245580026,
#   'with<>this': -8.463943096524712,
#   'over<>the': -9.023558884460135,
#   'loud<>,': -9.71670606502008,
#   'na<>buy': -10.409853245580026,
#   'drink<>selection': -9.71670606502008,
#   "n't<>bring": -10.409853245580026,
#   'some<>good': -9.71670606502008,
#   'see<>if': -10.409853245580026,
#   'she<>does': -9.71670606502008,
#   'a<>white': -9.71670606502008,
#   'the<>straw': -9.71670606502008,
#   'highlights<>the': -9.71670606502008,
#   'a<>defect': -10.409853245580026,
#   'superficial<>movie': -10.409853245580026,
#   'and<>lines': -10.409853245580026,
#   'bad<>idea': -10.409853245580026,
#   '<s><>cheap': -9.71670606502008,
#   'killings<>.': -10.409853245580026,
#   'right<>.': -8.618093776351971,
#   'now<>imagine': -10.409853245580026,
#   'zero<>stars': -10.409853245580026,
#   'interesting<>,': -9.71670606502008,
#   'movie<>a': -9.71670606502008,
#   'downtown<>juries': -9.71670606502008,
#   'on<>phone': -9.71670606502008,
#   'early<>70': -9.71670606502008,
#   'the<>success': -9.71670606502008,
#   'fo<>take': -9.71670606502008,
#   'is<>fabulous': -9.71670606502008,
#   'tied<>to': -10.409853245580026,
#   'virus<>.': -10.409853245580026,
#   'bothersome<>man': -9.71670606502008,
#   'palate<>of': -10.409853245580026,
#   'cheaply<>made': -10.409853245580026,
#   'fantastic<>afternoon': -9.71670606502008,
#   'one<>should': -9.71670606502008,
#   'embarrassing<>.': -10.409853245580026,
#   'put<>it': -9.71670606502008,
#   'numbers<>in': -10.409853245580026,
#   'date<>.': -9.71670606502008,
#   'were<>well-done': -9.71670606502008,
#   'overly<>expensive': -9.71670606502008,
#   'gives<>meaning': -9.71670606502008,
#   'of<>wines': -9.71670606502008,
#   'get<>2': -10.409853245580026,
#   'gere<>in': -10.409853245580026,
#   'energy<>.': -10.409853245580026,
#   'or<>steve': -9.71670606502008,
#   'the<>sweet': -9.71670606502008,
#   'opinion<>.': -9.71670606502008,
#   'eat<>in': -9.311240956911915,
#   "'d<>like": -9.71670606502008,
#   'catchy<>song': -9.71670606502008,
#   'colors<>!': -9.71670606502008,
#   'ratio<>made': -10.409853245580026,
#   'is<>still': -9.023558884460135,
#   '<s><>small': -9.71670606502008,
#   'sand<>concerning': -9.71670606502008,
#   ',<>simply': -9.71670606502008,
#   'back<>unless': -10.409853245580026,
#   'depicts<>,': -9.71670606502008,
#   ';<></s>': -9.71670606502008,
#   'establishment<>i': -10.409853245580026,
#   'nothing<>if': -10.409853245580026,
#   'think<>she': -9.71670606502008,
#   'practical<>setup': -9.71670606502008,
#   'whoever<>lived': -9.71670606502008,
#   'it<>.': -6.883492720963864,
#   'phone<>work': -9.71670606502008,
#   'humour<>and': -9.71670606502008,
#   'role<>as': -9.311240956911915,
#   'remember<>was': -10.409853245580026,
#   'became<>the': -10.409853245580026,
#   'dependant<>diabetic': -10.409853245580026,
#   'hair<>configuration': -10.409853245580026,
#   '-drinks<>took': -10.409853245580026,
#   '<s><>raw': -9.71670606502008,
#   'for<>hitchcock': -9.71670606502008,
#   'up<>against': -9.71670606502008,
#   'mobile<>phone': -9.311240956911915,
#   'sugary<>disaster': -10.409853245580026,
#   'her<>best': -9.71670606502008,
#   '<s><>enough': -9.71670606502008,
#   "'m<>sure": -10.409853245580026,
#   'the<>item': -10.409853245580026,
#   'the<>gentle-touch': -10.409853245580026,
#   'fantastic<>service': -9.71670606502008,
#   'swamp<>location': -9.71670606502008,
#   'cheap<>plastic': -10.409853245580026,
#   'lot<>.': -9.71670606502008,
#   'subpar<>food': -9.71670606502008,
#   'camera<>thats': -9.71670606502008,
#   'by<>removing': -10.409853245580026,
#   'again<>!': -9.311240956911915,
#   '510<>maintains': -9.71670606502008,
#   'be<>in': -9.311240956911915,
#   'small<>wave': -10.409853245580026,
#   'becomes<>a': -10.409853245580026,
#   'food<>ever': -9.71670606502008,
#   'your<>conversations': -10.409853245580026,
#   'drenched<>in': -9.71670606502008,
#   'marbles<>so': -10.409853245580026,
#   'try<>going': -10.409853245580026,
#   'garbage<>got': -10.409853245580026,
#   'enjoy<>is': -10.409853245580026,
#   'a<>bonus': -9.71670606502008,
#   'restaurant<>feel': -9.71670606502008,
#   'much<>been': -9.71670606502008,
#   'came<>over': -10.409853245580026,
#   'always<>a': -8.800415333145924,
#   'far<>and': -9.71670606502008,
#   'since<>our': -9.71670606502008,
#   'world<>!': -9.71670606502008,
#   'tv<>...': -9.71670606502008,
#   'mess<>.': -10.409853245580026,
#   '<s><>just': -8.618093776351971,
#   'warm<>feeling': -9.71670606502008,
#   'were<>greeted': -9.71670606502008,
#   'return<>the': -10.409853245580026,
#   'car<>with': -9.71670606502008,
#   'he<>humiliated': -10.409853245580026,
#   'plays<>angela': -10.409853245580026,
#   'good<>show': -9.71670606502008,
#   'be<>the': -9.023558884460135,
#   'of<>two': -9.71670606502008,
#   'i<>thought': -8.800415333145924,
#   'rude<>and': -10.409853245580026,
#   'hearts<>of': -10.409853245580026,
#   '<s><>voice': -9.71670606502008,
#   'been<>working': -9.311240956911915,
#   'with<>that': -9.71670606502008,
#   'a<>unique': -9.311240956911915,
#   'was<>also': -8.618093776351971,
#   'colder<>.': -9.71670606502008,
#   ',<>gorman': -9.71670606502008,
#   'what<>i': -8.618093776351971,
#   'scream<>movies': -9.71670606502008,
#   'bland<>.': -10.409853245580026,
#   'going<>there': -10.409853245580026,
#   'cases<>such': -10.409853245580026,
#   'articulated<>quite': -9.71670606502008,
#   'especially<>designed': -9.71670606502008,
#   'little<>item': -9.71670606502008,
#   'up<>trying': -10.409853245580026,
#   'was<>brilliant': -9.71670606502008,
#   'to<>par': -10.409853245580026,
#   'lunch<>here': -9.71670606502008,
#   'even<>remotely': -10.409853245580026,
#   'stale<>.': -10.409853245580026,
#   'disagree<>with': -10.409853245580026,
#   'she<>would': -10.409853245580026,
#   'a<>distant': -9.71670606502008,
#   'hayao<>miyazaki': -9.71670606502008,
#   'childhood<>.': -9.71670606502008,
#   'received<>from': -10.409853245580026,
#   'car<>will': -10.409853245580026,
#   'sharp<>.': -9.71670606502008,
#   'a<>recurring': -9.71670606502008,
#   'pay<>to': -10.409853245580026,
#   'how<>joey': -10.409853245580026,
#   'not<>like': -10.409853245580026,
#   'in<>real': -9.71670606502008,
#   'great<>actress': -9.71670606502008,
#   'but<>above': -9.71670606502008,
#   'the<>audience': -9.71670606502008,
#   "'s<>.": -9.311240956911915,
#   'else<>involved': -10.409853245580026,
#   'hat<>or': -10.409853245580026,
#   'sandra<>bullock': -10.409853245580026,
#   '<s><>host': -10.409853245580026,
#   'pretty<>much': -9.71670606502008,
#   'beef<>sandwich': -9.311240956911915,
#   'had<>!': -9.311240956911915,
#   "n't<>act": -10.409853245580026,
#   'the<>descriptions': -10.409853245580026,
#   'the<>tuna': -10.409853245580026,
#   'most<>annoying': -10.409853245580026,
#   '&<>costumes': -9.71670606502008,
#   'is<>beyond': -10.409853245580026,
#   'lilt<>in': -9.71670606502008,
#   'many<>other': -10.409853245580026,
#   'material<>and': -10.409853245580026,
#   'eargels<>fit': -9.71670606502008,
#   'leather<>case': -9.71670606502008,
#   "n't<>the": -10.409853245580026,
#   'we<>loved': -9.71670606502008,
#   'kept<>getting': -10.409853245580026,
#   'best<>movies': -9.311240956911915,
#   'it<>any': -10.409853245580026,
#   'or<>ala': -10.409853245580026,
#   'very<>fast': -9.71670606502008,
#   'taste<>(': -9.71670606502008,
#   'order<>dessert': -9.71670606502008,
#   'get<>my': -10.409853245580026,
#   'after<>finally': -9.71670606502008,
#   'is<>doughy': -10.409853245580026,
#   'many<>awards': -10.409853245580026,
#   '<s><>if': -8.107268152585979,
#   'character<>he': -9.71670606502008,
#   'generates<>is': -9.71670606502008,
#   'beeping<>,': -10.409853245580026,
#   'a<>hat': -10.409853245580026,
#   'them<>a': -9.71670606502008,
#   'so<>many': -9.311240956911915,
#   'store<>sells': -9.71670606502008,
#   'every<>one': -9.71670606502008,
#   'veteran<>actors': -9.71670606502008,
#   'felt<>too': -10.409853245580026,
#   'follow<>from': -10.409853245580026,
#   'essence<>of': -9.71670606502008,
#   'dates<>.': -9.71670606502008,
#   'shocked<>because': -10.409853245580026,
#   'of<>hitchcock': -9.71670606502008,
#   'are<>starving': -10.409853245580026,
#   'an<>appetizer': -10.409853245580026,
#   'at<>nobu': -9.71670606502008,
#   'i<>find': -9.71670606502008,
#   'from<>its': -9.71670606502008,
#   'charles<>is': -9.71670606502008,
#   'happened<>in': -10.409853245580026,
#   'story<>different': -9.71670606502008,
#   't<>;': -10.409853245580026,
#   'restaurant<>is': -9.311240956911915,
#   'it<>2': -10.409853245580026,
#   'unwelcome<>...': -10.409853245580026,
#   'anticipated<>.': -10.409853245580026,
#   'amazing<>...': -9.311240956911915,
#   '(<>some': -10.409853245580026,
#   'dollars<>because': -10.409853245580026,
#   'music<>on': -10.409853245580026,
#   '.<>)': -9.311240956911915,
#   'carrell<>ca': -10.409853245580026,
#   'may<>not': -10.409853245580026,
#   'least<>said': -10.409853245580026,
#   'ant<>is': -9.71670606502008,
#   'an<>integral': -9.71670606502008,
#   'the<>homemade': -9.71670606502008,
#   'contains<>the': -9.71670606502008,
#   '<s><>everyone': -9.311240956911915,
#   'this<>pretentious': -10.409853245580026,
#   'i<>tried': -9.71670606502008,
#   'cream<>sauce': -10.409853245580026,
#   'power<>via': -9.71670606502008,
#   'have<>dreamed': -9.71670606502008,
#   'walk<>out': -10.409853245580026,
#   "r<>''": -9.71670606502008,
#   'unbearably<>predictably': -10.409853245580026,
#   'many<>movies': -9.71670606502008,
#   'very<>disappointing': -10.409853245580026,
#   'the<>witticisms': -10.409853245580026,
#   'three<>different': -10.409853245580026,
#   'food<>until': -9.71670606502008,
#   'unfaithful<>,': -10.409853245580026,
#   'and<>then': -10.409853245580026,
#   'table<>thought': -10.409853245580026,
#   'my<>purchase': -9.023558884460135,
#   'quality<>!': -9.71670606502008,
#   'genuine<>palm': -10.409853245580026,
#   'movie<>contained': -9.71670606502008,
#   'shakespear<>fans': -9.71670606502008,
#   ',<>quite': -10.409853245580026,
#   'of<>slimy': -9.71670606502008,
#   'never<>walked': -10.409853245580026,
#   'owns<>the': -9.71670606502008,
#   'lasting<>impression': -9.71670606502008,
#   'rarely<>a': -10.409853245580026,
#   "joe<>'s": -10.409853245580026,
#   'be<>made': -9.71670606502008,
#   'phoenix<>that': -9.71670606502008,
#   'townsend<>)': -9.71670606502008,
#   'many<>words': -9.71670606502008,
#   'noir-crime-drama<>,': -9.71670606502008,
#   'evokes<>many': -9.71670606502008,
#   'no<>bubbling': -9.71670606502008,
#   ...}}

# %%
testing12 = "excellent"
classifier1.prediction(testing12)
# Out:
# 1

# %%
classifier1.dictionaryOfWords
# Out:
# {'pretty<>trippy',
#  'quality<>product',
#  'sister<>has',
#  'clip<>going',
#  'tick<>sound',
#  'turn<>it',
#  'the<>gently',
#  'chickens<>with',
#  'the<>sergeant',
#  'soup<>-',
#  'characters<>are',
#  'some<>way',
#  '5<>)',
#  'wooden<>floor',
#  'something<>.',
#  'well-done<>.',
#  'of<>boost',
#  'and<>never',
#  "'ll<>never",
#  'missed<>a',
#  'after<>3',
#  'a<>heart',
#  'any<>of',
#  'junk<>.',
#  'hot<>and',
#  'this<>gifted',
#  "n't<>really",
#  'your<>ear',
#  'unwrapped<>it',
#  'refused<>to',
#  'restaurant<>highlighted',
#  'talent<>is',
#  'thanks<>good',
#  'service<>here',
#  'hostess<>and',
#  'flawless<>connection',
#  ',<>bitches',
#  'a<>way',
#  'acting<>sucked',
#  'this<>for',
#  'depth<>.',
#  'not<>take',
#  "'s<>auto-answer",
#  'angle<>and',
#  '3<>months',
#  'they<>keep',
#  'was<>clear',
#  'a<>good',
#  '<s><>probably',
#  'we<>asked',
#  'have<>eaten',
#  '<s><>things',
#  'the<>trap',
#  'my<>apple',
#  'movies<>like',
#  'work<>in',
#  'internet<>access',
#  'to<>look',
#  'both<>of',
#  "'m<>driving",
#  'i<>basically',
#  'crãªpe<>was',
#  'clear<>reception',
#  "'s<>the",
#  'pho<>!',
#  'sydney<>greenstreet',
#  'his<>childhood',
#  ',<>there',
#  'exactly<>how',
#  'crostini<>that',
#  'really<>ugly',
#  'are<>supposed',
#  'three<>sizes',
#  'very<>unreliable',
#  'this<>tops',
#  'motorola<>q',
#  'provided<>excellent',
#  'shows<>of',
#  'wrong<>size',
#  'amazing<>meal',
#  'these<>.',
#  'overpriced<>.',
#  'the<>scenes',
#  'everything<>to',
#  'other<>end',
#  'blanket<>of',
#  'interacting<>with',
#  'waaaaaayyyyyyyyyy<>over',
#  'can<>say',
#  'work<>very',
#  'told<>friends',
#  'crowd<>pleaser',
#  'clearly<>.',
#  'far<>better',
#  'central<>character',
#  'so<>this',
#  'total<>brunch',
#  '(<>it',
#  'what<>other',
#  'how<>cool',
#  'he<>actually',
#  'enjoyable<>movie',
#  'address<>book',
#  'was<>cooked',
#  'a<>feature',
#  'no<>bigger',
#  ',<>&',
#  'well<>below',
#  'contstruct<>hinge',
#  'are<>tremendous',
#  'non-linear<>narration',
#  'many<>handsfree',
#  'all..<>i',
#  'awful<>,',
#  'all<>it',
#  'it<>somehow',
#  'the<>stuff',
#  'her<>character',
#  'eggplant<>with',
#  'great<>he',
#  'lightly<>against',
#  'bumpers<>with',
#  'perhaps<>contributory',
#  'wow<>,',
#  'barcelona<>and',
#  'on<>fox',
#  'one<>big',
#  'the<>chicken',
#  'tops<>the',
#  'garbage<>in',
#  'this<>a',
#  'film<>did',
#  'place<>on',
#  '1/2<>a',
#  'party<>to',
#  'and<>has',
#  'art<>.',
#  'mesquite<>flavor',
#  'bother<>-',
#  'for<>wasting',
#  '<s><>omg',
#  'is<>interesting',
#  'fresh<>fish',
#  'cannoli<>are',
#  '<s><>favorite',
#  'to<>identify',
#  'to<>dislike',
#  'quickly<>and',
#  '2<>videos',
#  'pictures<>with',
#  'even<>says',
#  'first<>and',
#  'pleasantly<>suprised',
#  'pcs<>samsung',
#  'to<>sit',
#  'just<>predictable',
#  'made<>me',
#  '<s><>maybe',
#  'being<>like',
#  '2<>.',
#  '-<>service',
#  'it<>to',
#  'tasty<>bowl',
#  'singing<>.',
#  'disappointed<>.',
#  'paid<>.',
#  'script<>is',
#  'date<>night',
#  'inspiring<>to',
#  'jokes<>to',
#  'the<>major',
#  'fail<>.',
#  'with<>three',
#  'the<>amount',
#  'all<>good',
#  'or<>win',
#  'ringtones<>or',
#  'fact<>joe',
#  'the<>downtown',
#  'into<>the',
#  'trying<>hard',
#  'they<>debated',
#  'tried<>to',
#  'to<>rice',
#  'catching<>the',
#  'being<>perfect',
#  'is<>when',
#  'stupid<>.',
#  'alike<>.',
#  'folks<>at',
#  'to<>seperate',
#  'am<>so',
#  'was<>creamy',
#  'i<>kept',
#  'increase<>the',
#  'up<>before',
#  '<s><>first',
#  'unless<>i',
#  'movie<>``',
#  "''<>in",
#  'bordered<>on',
#  'ear<>loops',
#  'them<>were',
#  'tables<>outside',
#  'patriotism<>that',
#  'else<>.',
#  'the<>logitech',
#  'from<>riz',
#  'form<>of',
#  'earth<>as',
#  'money<>with',
#  'this<>sooner',
#  'just<>becomes',
#  'also<>incredible',
#  'dissapointing<>performance',
#  'and<>white',
#  "prelude<>''",
#  'the<>creature',
#  'boring<>moment',
#  'the<>charge',
#  'should<>and',
#  '--<>at',
#  'for<>the',
#  'vodka<>excellent',
#  'natural<>eye',
#  'servers<>are',
#  'owning<>an',
#  'and<>being',
#  'freezes<>frequently4',
#  'unhealthy<>meal',
#  'made<>wrong',
#  'brian<>keith',
#  '3<>times',
#  'become<>a',
#  'to<>give',
#  'that<>again',
#  'heart<>at',
#  'solid<>keyboard',
#  'end<>could',
#  'display<>,',
#  'the<>cutouts',
#  'no<>one',
#  'expect<>from',
#  'a<>european',
#  'in<>market',
#  'last<>)',
#  'version<>,',
#  'was<>mediocre',
#  '2<>cellphones',
#  '<s><>penne',
#  'compelling<>,',
#  ',<>aerial',
#  'still<>great',
#  'acting<>is',
#  'it<>are',
#  '(<>shocking',
#  'are<>difficult',
#  'needs<>a',
#  'it<>off',
#  'patron<>!',
#  'me<>know',
#  'quick<>glance',
#  'a<>truly',
#  'great<>earpiece',
#  'for<>and',
#  'late<>may',
#  'and<>another',
#  'to<>really',
#  'almost<>non-existent',
#  'you<>occupied',
#  'big<>.',
#  'casing<>around',
#  'calls<>drop',
#  '(<>env',
#  'and<>was',
#  'gooodd<>.',
#  'to<>life',
#  "i<>'d",
#  'one<>,',
#  'but<>more',
#  'wouldnt<>see',
#  '<s><>appetite',
#  'i<>gave',
#  'had<>some',
#  'in<>length',
#  'and<>taste',
#  'dialogue<>,',
#  'exactly<>what',
#  'bluetooth<>headset',
#  'worst<>purchase',
#  'called<>that-sucked',
#  'recover<>.',
#  'not<>answer',
#  'this<>understated',
#  'recommend<>this',
#  'an<>outstanding',
#  'of<>10',
#  'bathroom<>is',
#  'very<>bland',
#  '<s><>nice',
#  'massive<>levels',
#  'a<>toro',
#  'read<>other',
#  'the<>zombie-students',
#  'falling<>out',
#  'kindle<>fire',
#  ',<>``',
#  'a<>hard',
#  'the<>aerial',
#  'easily<>because',
#  'point<>.',
#  'burgers<>.',
#  '<s><>disappointing',
#  '<s><>actually',
#  'got<>food',
#  'and<>photography',
#  'moment<>,',
#  'against<>any',
#  'on<>blacktop',
#  'sauce<>to',
#  'psychological<>motivations',
#  'many<>years',
#  ',<>sound',
#  'and<>there',
#  'most<>famous',
#  'marion<>has',
#  'get<>it',
#  'john<>hay',
#  'ok<>(',
#  'sound<>directly',
#  "n't<>say",
#  'ends<>.',
#  'find<>out',
#  '--<>it',
#  'low<>tolerance',
#  'deserves<>strong',
#  'be<>given',
#  'a<>movie',
#  'right<>or',
#  'stewart<>is',
#  'ride<>so',
#  '<s><>crostini',
#  'not<>what',
#  'a<>thriller',
#  'time-waster<>of',
#  '<s><>motorola',
#  'dit<>not',
#  ',<>came',
#  ',<>radiant',
#  'here<>!',
#  'daughter<>out',
#  'horror<>movies',
#  'to<>return',
#  'and<>my',
#  'clearly<>can',
#  'of<>how',
#  'listener<>)',
#  'blandly<>written',
#  'selections<>of',
#  'performance<>by',
#  'condiment<>dispenser',
#  'good<>addition',
#  'headset<>for',
#  'vocal<>that',
#  'as<>advertised',
#  'occasional<>pats',
#  'disappointment<>was',
#  'nice<>color',
#  'are<>combos',
#  'find<>hours',
#  'spices<>and',
#  'of<>close-up',
#  'after<>.',
#  'as<>for',
#  'film<>at',
#  '<s><>honeslty',
#  'the<>salmon',
#  '...<>then',
#  'face<>.',
#  'two<>were',
#  'of<>to',
#  'be<>of',
#  'make<>them',
#  'of<>legit',
#  'and<>better',
#  'wireless<>is',
#  'atmosphere<>here',
#  'seems<>to',
#  'his<>head',
#  'theater<>with',
#  'clearly<>does',
#  'best<>seafood',
#  'line<>:',
#  'all<>the',
#  'styles<>like',
#  'hybrid<>palmtop/camera/cellphone',
#  'delicious<>nyc',
#  'between<>martin',
#  'latin<>that',
#  'ambience<>is',
#  'and<>music',
#  'anything<>left',
#  'verizon<>tech',
#  'restaurant<>was',
#  'also<>boasts',
#  'even<>video',
#  'mature<>age',
#  'very<>frustrated',
#  'see<>both',
#  'chick<>flick',
#  '2<>or',
#  ',<>are',
#  '<s><>bacon',
#  'the<>patio',
#  'for<>all',
#  'was<>slow',
#  'deal<>with',
#  "'s<>amazing",
#  'both<>films',
#  "n't<>missed",
#  'works<>fine',
#  'peas<>and',
#  'and<>fell',
#  'at<>least',
#  'everything<>it',
#  'delicate<>and',
#  ',<>verbal',
#  'punish<>the',
#  '<s><>however-the',
#  'cranberry<>...',
#  'pretty<>amazing',
#  'real<>plot',
#  'a<>coupon',
#  '<s><>display',
#  'folks<>.',
#  'the<>wife',
#  'recent<>experience',
#  'reservation<>.',
#  'going<>up',
#  'i<>fast',
#  'starring<>jaclyn',
#  'be<>honest',
#  'this<>poorly',
#  'keyboard<>is',
#  'to<>again',
#  'voyage<>of',
#  'would<>avoid',
#  'mickey<>playing',
#  'dead<>on',
#  'here<>every',
#  'made<>another',
#  'monster<>movie',
#  'are<>a',
#  ',<>treachery',
#  'empty<>and',
#  'early<>film',
#  'to<>those',
#  'the<>next',
#  'bond<>for',
#  'one<>who',
#  'battery<>,',
#  'reporter<>who',
#  'spicy<>was',
#  'recommend<>purchasing',
#  'was<>more',
#  'stayed<>professional',
#  'applifies<>everything',
#  'get<>any',
#  'was<>below',
#  'when<>our',
#  'way<>through',
#  'the<>script',
#  'that<>came',
#  'deliciously<>seasoned',
#  'ever<>see',
#  'soyo<>technology',
#  'both<>senses',
#  'haggis<>for',
#  'checking<>out',
#  'ps<>the',
#  'dee<>snider',
#  '<s><>lightweight',
#  'a<>disapoinment',
#  ',<>confusing',
#  'have<>been',
#  'use<>the',
#  'great<>menu',
#  'living/working<>in',
#  'scene<>)',
#  'talk<>down',
#  'the<>charger',
#  'play<>it',
#  'staff<>was',
#  'i<>was',
#  'just<>reading',
#  'i<>want',
#  'veggitarian<>platter',
#  "n't<>ever",
#  'free<>with',
#  'opening<>sequence',
#  'big<>drawback',
#  'top<>of',
#  'is<>sloppy',
#  'development<>of',
#  "n't<>waste",
#  'which<>we',
#  'minute<>.',
#  "has<>n't",
#  ',<>who',
#  'this<>endearing',
#  "'re<>not",
#  'in<>vegas',
#  'fi<>film',
#  'mute<>.',
#  'in<>quantity',
#  "'s<>poised",
#  'it<>looses',
#  'also<>can',
#  'needed<>.',
#  'movie<>today',
#  'be<>,',
#  'is<>slim',
#  'this<>pandering',
#  'other<>cases',
#  'flaws<>.',
#  'quaint<>,',
#  'my<>step',
#  'sucked<>.',
#  'truffle<>.',
#  'sinking<>feeling',
#  'tv<>?',
#  ',<>ridiculous',
#  'to<>show',
#  'order<>.',
#  'had<>this',
#  'is<>broken',
#  'pg-13<>film',
#  'and<>their',
#  'a<>breakfast',
#  'expect<>them',
#  'dedication<>to',
#  'fairly<>clean',
#  'disapppointment<>with',
#  'he<>succeeded',
#  'wholesome<>family',
#  '--<>look',
#  'spoilers<>)',
#  'but<>shouting',
#  'this<>will',
#  'to<>fans',
#  '<s><>bland',
#  'by<>this',
#  'thing<>worse',
#  'directing<>make',
#  'loves<>roasted',
#  'course<>we',
#  "'s<>share",
#  'the<>pans',
#  'of<>our',
#  'excellent<>drama',
#  'aailiyah<>was',
#  'calligraphy<>wall',
#  'every<>joke',
#  'them<>self',
#  'writing<>bad',
#  'now<>the',
#  'this<>happening',
#  'ended<>,',
#  'quinn<>.',
#  'tech<>support',
#  'from<>tucson',
#  'and<>generous',
#  'how<>retarded',
#  'of<>nuns',
#  'other<>nationalities',
#  'that<>fresh',
#  'for<>anyone',
#  'is<>john',
#  'more<>intelligent',
#  'the<>job',
#  'i<>checked',
#  'let<>alone',
#  '...<>and',
#  'clip<>.',
#  'are<>often',
#  'not<>rent',
#  'with<>his',
#  'disappointed<>!',
#  'began<>before',
#  'name<>callings',
#  'the<>money',
#  'awesome<>device',
#  'chemistry<>,',
#  'to<>change',
#  'family<>atmosphere',
#  'the<>possibility',
#  'area<>.',
#  'and<>seated',
#  'for<>23',
#  'of<>long',
#  'one<>considers',
#  'was<>robert',
#  'frankly<>,',
#  'drain<>your',
#  'generous<>in',
#  'are<>good',
#  'perfectly<>so',
#  'that<>not',
#  'should<>.',
#  'is<>soooo',
#  'low<>budget',
#  'going<>for',
#  'job<>done',
#  'a<>flick',
#  '<s><>a',
#  'was<>stale',
#  'put<>their',
#  'riveted<>to',
#  'painful<>to',
#  'disappointing<>aspects',
#  'be<>amazing',
#  'extra<>plus',
#  'heat<>.',
#  'chicken<>on',
#  'the<>cape',
#  'service<>experience',
#  'now<>i',
#  'vegetables<>)',
#  'here<>did',
#  'and<>charlie',
#  'pics<>are',
#  'spot<>when',
#  "'re<>looking",
#  'wow<>!',
#  'in<>``',
#  ',<>or',
#  'ok<>)',
#  'every<>element',
#  'are<>enough',
#  'his<>performance',
#  'great<>item',
#  '<s><>uncomfortable',
#  'bad<>customer',
#  'riingtones<>are',
#  'town<>for',
#  'not<>use',
#  'who<>changes',
#  'faux<>home',
#  'was<>still',
#  '2<>days',
#  'still<>,',
#  'for<>dessert',
#  'spot<>on',
#  'sandwich<>,',
#  'the<>great',
#  'film<>over',
#  'and<>cumbersome',
#  'my<>through',
#  'ice<>cold',
#  "'m<>trying",
#  'the<>spaghetti',
#  '<s><>phone',
#  'price<>i.e',
#  'worked<>and',
#  'little<>comedy',
#  'years<>old',
#  'but<>which',
#  '-<>a',
#  'when<>he',
#  'by<>strident',
#  'new<>there',
#  '<s><>once',
#  'skimp<>on',
#  'contain<>peanuts',
#  "i<>'ll",
#  '/<>phone',
#  'war<>which',
#  'look<>away',
#  'times<>-',
#  'to<>eat',
#  'a<>little',
#  'because<>they',
#  'portions<>are',
#  'service<>people',
#  'which<>she',
#  'film<>highlights',
#  'even<>has',
#  'should<>have',
#  'the<>onion',
#  'a<>weird',
#  'the<>han',
#  'i<>would',
#  'big<>flawed',
#  'and<>clarity',
#  'is<>long',
#  'they<>would',
#  ')<>you',
#  'somehow<>kept',
#  'are<>delicious',
#  'two<>main',
#  'in<>1928',
#  'that<>the',
#  'continuity<>,',
#  'builders<>were',
#  'wasted<>to',
#  'broke<>.',
#  'gripping<>,',
#  'over<>a',
#  'film<>artist',
#  'of<>s***',
#  'hell<>you',
#  'see<>.',
#  'is<>clearly',
#  'functions<>.',
#  'a<>fabulous',
#  'with<>everything',
#  'all<>enjoy',
#  'earpieces<>provided',
#  'on<>it',
#  'noise<>cancelling',
#  'i<>realized',
#  'a<>bunch',
#  'more<>attention',
#  'the<>ball',
#  'not<>overly',
#  'you<>love',
#  'with<>this',
#  'over<>the',
#  'loud<>,',
#  'na<>buy',
#  'drink<>selection',
#  "n't<>bring",
#  'some<>good',
#  'see<>if',
#  'she<>does',
#  'a<>white',
#  'the<>straw',
#  'highlights<>the',
#  'a<>defect',
#  'superficial<>movie',
#  'and<>lines',
#  'bad<>idea',
#  '<s><>cheap',
#  'killings<>.',
#  'right<>.',
#  'now<>imagine',
#  'zero<>stars',
#  'interesting<>,',
#  'movie<>a',
#  'downtown<>juries',
#  'on<>phone',
#  'early<>70',
#  'the<>success',
#  'fo<>take',
#  'is<>fabulous',
#  'tied<>to',
#  'virus<>.',
#  'bothersome<>man',
#  'palate<>of',
#  'cheaply<>made',
#  'fantastic<>afternoon',
#  'one<>should',
#  'embarrassing<>.',
#  'put<>it',
#  'numbers<>in',
#  'date<>.',
#  'were<>well-done',
#  'overly<>expensive',
#  'gives<>meaning',
#  'of<>wines',
#  'get<>2',
#  'gere<>in',
#  'energy<>.',
#  'or<>steve',
#  'the<>sweet',
#  'opinion<>.',
#  'eat<>in',
#  "'d<>like",
#  'catchy<>song',
#  'colors<>!',
#  'ratio<>made',
#  'is<>still',
#  '<s><>small',
#  'sand<>concerning',
#  ',<>simply',
#  'back<>unless',
#  'depicts<>,',
#  ';<></s>',
#  'establishment<>i',
#  'nothing<>if',
#  'think<>she',
#  'practical<>setup',
#  'whoever<>lived',
#  'it<>.',
#  'phone<>work',
#  'humour<>and',
#  'role<>as',
#  'remember<>was',
#  'became<>the',
#  'dependant<>diabetic',
#  'hair<>configuration',
#  '-drinks<>took',
#  '<s><>raw',
#  'for<>hitchcock',
#  'up<>against',
#  'mobile<>phone',
#  'sugary<>disaster',
#  'her<>best',
#  '<s><>enough',
#  "'m<>sure",
#  'the<>item',
#  'the<>gentle-touch',
#  'fantastic<>service',
#  'swamp<>location',
#  'cheap<>plastic',
#  'lot<>.',
#  'subpar<>food',
#  'camera<>thats',
#  'by<>removing',
#  'again<>!',
#  '510<>maintains',
#  'be<>in',
#  'small<>wave',
#  'becomes<>a',
#  'food<>ever',
#  'your<>conversations',
#  'drenched<>in',
#  'marbles<>so',
#  'try<>going',
#  'garbage<>got',
#  'enjoy<>is',
#  'a<>bonus',
#  'restaurant<>feel',
#  'much<>been',
#  'came<>over',
#  'always<>a',
#  'far<>and',
#  'since<>our',
#  'world<>!',
#  'tv<>...',
#  'mess<>.',
#  '<s><>just',
#  'warm<>feeling',
#  'were<>greeted',
#  'return<>the',
#  'car<>with',
#  'he<>humiliated',
#  'plays<>angela',
#  'good<>show',
#  'be<>the',
#  'of<>two',
#  'i<>thought',
#  'rude<>and',
#  'hearts<>of',
#  '<s><>voice',
#  'been<>working',
#  'with<>that',
#  'a<>unique',
#  'was<>also',
#  'colder<>.',
#  ',<>gorman',
#  'what<>i',
#  'scream<>movies',
#  'bland<>.',
#  'going<>there',
#  'cases<>such',
#  'articulated<>quite',
#  'especially<>designed',
#  'little<>item',
#  'up<>trying',
#  'was<>brilliant',
#  'to<>par',
#  'lunch<>here',
#  'even<>remotely',
#  'stale<>.',
#  'disagree<>with',
#  'she<>would',
#  'a<>distant',
#  'hayao<>miyazaki',
#  'childhood<>.',
#  'received<>from',
#  'car<>will',
#  'sharp<>.',
#  'a<>recurring',
#  'pay<>to',
#  'how<>joey',
#  'not<>like',
#  'in<>real',
#  'great<>actress',
#  'but<>above',
#  'the<>audience',
#  "'s<>.",
#  'else<>involved',
#  'hat<>or',
#  'sandra<>bullock',
#  '<s><>host',
#  'pretty<>much',
#  'beef<>sandwich',
#  'had<>!',
#  "n't<>act",
#  'the<>descriptions',
#  'the<>tuna',
#  'most<>annoying',
#  '&<>costumes',
#  'is<>beyond',
#  'lilt<>in',
#  'many<>other',
#  'material<>and',
#  'eargels<>fit',
#  'leather<>case',
#  "n't<>the",
#  'we<>loved',
#  'kept<>getting',
#  'best<>movies',
#  'it<>any',
#  'or<>ala',
#  'very<>fast',
#  'taste<>(',
#  'order<>dessert',
#  'get<>my',
#  'after<>finally',
#  'is<>doughy',
#  'many<>awards',
#  '<s><>if',
#  'character<>he',
#  'generates<>is',
#  'beeping<>,',
#  'a<>hat',
#  'them<>a',
#  'so<>many',
#  'store<>sells',
#  'every<>one',
#  'veteran<>actors',
#  'felt<>too',
#  'follow<>from',
#  'essence<>of',
#  'dates<>.',
#  'shocked<>because',
#  'of<>hitchcock',
#  'are<>starving',
#  'an<>appetizer',
#  'at<>nobu',
#  'i<>find',
#  'from<>its',
#  'charles<>is',
#  'happened<>in',
#  'story<>different',
#  't<>;',
#  'restaurant<>is',
#  'it<>2',
#  'unwelcome<>...',
#  'anticipated<>.',
#  'amazing<>...',
#  '(<>some',
#  'dollars<>because',
#  'music<>on',
#  '.<>)',
#  'carrell<>ca',
#  'may<>not',
#  'least<>said',
#  'ant<>is',
#  'an<>integral',
#  'the<>homemade',
#  'contains<>the',
#  '<s><>everyone',
#  'this<>pretentious',
#  'i<>tried',
#  'cream<>sauce',
#  'power<>via',
#  'have<>dreamed',
#  'walk<>out',
#  "r<>''",
#  'unbearably<>predictably',
#  'many<>movies',
#  'very<>disappointing',
#  'the<>witticisms',
#  'three<>different',
#  'food<>until',
#  'unfaithful<>,',
#  'and<>then',
#  'table<>thought',
#  'my<>purchase',
#  'quality<>!',
#  'genuine<>palm',
#  'movie<>contained',
#  'shakespear<>fans',
#  ',<>quite',
#  'of<>slimy',
#  'never<>walked',
#  'owns<>the',
#  'lasting<>impression',
#  'rarely<>a',
#  "joe<>'s",
#  'be<>made',
#  'phoenix<>that',
#  'townsend<>)',
#  'many<>words',
#  'noir-crime-drama<>,',
#  'evokes<>many',
#  'no<>bubbling',
#  ...}

# %%
#classifier1.testThisFile("./Project One/sentiment_labelled_sentences/amazon_cells_labelled.txt")
classifier1.accuracy("./Project One/resultstxt","./Project One/sentiment_labelled_sentences/amazon_cells_labelled.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7f91f1ae30f0> in <module>()
#       1 #classifier1.testThisFile("./Project One/sentiment_labelled_sentences/amazon_cells_labelled.txt")
# ----> 2 classifier1.accuracy("./Project One/resultstxt","./Project One/sentiment_labelled_sentences/amazon_cells_labelled.txt")
#
# <ipython-input-1-28db6fe79dc4> in accuracy(self, output, actual)
#     139         with open(actual) as m:
#     140             for line in m.readlines():
# --> 141                 mutupo = int(line)
#     142                 actualColumns.append(mutupo)
#     143
#
# ValueError: invalid literal for int() with base 10: 'So there is no way for me to plug it in here in the US unless I go by a converter.\t0\n'
